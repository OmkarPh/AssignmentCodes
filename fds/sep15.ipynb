# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.DataFrame({ "col1": [1,2,3,4], "col2": [5,6,7,4] })
df2 = pd.DataFrame({ "col1": [11,12,13,14], "col2": [15,16,17,18]})

# %%
df1
# Out:
#    col1  col2
# 0     1     5
# 1     2     6
# 2     3     7
# 3     4     4

# %%
df2
# Out:
#    col1  col2
# 0    11    15
# 1    12    16
# 2    13    17
# 3    14    18

# %%
pd.concat([df1, df2])
# Out:
#    col1  col2
# 0     1     5
# 1     2     6
# 2     3     7
# 3     4     4
# 0    11    15
# 1    12    16
# 2    13    17
# 3    14    18

# %%
pd.concat([df1, df2], axis=1)
# Out:
#    col1  col2  col1  col2
# 0     1     5    11    15
# 1     2     6    12    16
# 2     3     7    13    17
# 3     4     4    14    18

# %%
df1['col3'] = df1['col1'] + df1['col2']
df1
# Out:
#    col1  col2  col3
# 0     1     5     6
# 1     2     6     8
# 2     3     7    10
# 3     4     4     8

# %%
display([df1, df2])
# Out:
# [   col1  col2  col3
#  0     1     5     6
#  1     2     6     8
#  2     3     7    10
#  3     4     4     8,
#     col1  col2
#  0    11    15
#  1    12    16
#  2    13    17
#  3    14    18]

# %%
pd.concat([df1, df2])
# Out:
#    col1  col2  col3
# 0     1     5   6.0
# 1     2     6   8.0
# 2     3     7  10.0
# 3     4     4   8.0
# 0    11    15   NaN
# 1    12    16   NaN
# 2    13    17   NaN
# 3    14    18   NaN

# %%
df1
# Out:
#    col1  col2  col3
# 0     1     5     6
# 1     2     6     8
# 2     3     7    10
# 3     4     4     8

# %%
df2
# Out:
#    col1  col2
# 0    11    15
# 1    12    16
# 2    13    17
# 3    14    18

# %%
df1+df2
# Out:
#    col1  col2  col3
# 0    12    20   NaN
# 1    14    22   NaN
# 2    16    24   NaN
# 3    18    22   NaN

# %%
df2 - df1
# Out:
#    col1  col2  col3
# 0    10    10   NaN
# 1    10    10   NaN
# 2    10    10   NaN
# 3    10    14   NaN

# %%
df1 * df2
# Out:
#    col1  col2  col3
# 0    11    75   NaN
# 1    24    96   NaN
# 2    39   119   NaN
# 3    56    72   NaN

# %%
df_1 = pd.DataFrame({
  "col1":[1,2,3,4], "col2": [5,6,7,8], "col3": [True, False, False, True], "col4": ["a", "b", "c", "d"]
})
df_2 = pd.DataFrame({
  "col1":[11,12,13,14], "coll": [15,16,17,18], "col3": [True, False, True, False], "col4": ["e","f","g", "h"]
})

# %%
df_1
# Out:
#    col1  col2   col3 col4
# 0     1     5   True    a
# 1     2     6  False    b
# 2     3     7  False    c
# 3     4     8   True    d

# %%
df_2
# Out:
#    col1  coll   col3 col4
# 0    11    15   True    e
# 1    12    16  False    f
# 2    13    17   True    g
# 3    14    18  False    h

# %%
df_1 + df_2
# Out:
#    col1  col2   col3 col4  coll
# 0    12   NaN   True   ae   NaN
# 1    14   NaN  False   bf   NaN
# 2    16   NaN   True   cg   NaN
# 3    18   NaN   True   dh   NaN

# %%
df_1 - df_2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/omkar/projects/assignments/fds/sep15.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell:/Users/omkar/projects/assignments/fds/sep15.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> df_1 - df_2
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
#     193 def __sub__(self, other):
# --> 194     return self._arith_method(other, operator.sub)
#
# ...

# %%
df_3 = pd.DataFrame({
  "col1":[1,2,3,4], "col2": [5,6,7,8], "col3": [True, False, False, True], "col4": ["a", "b", "c", "d"]
})
df_4 = pd.DataFrame({
  "col1": [True, False, True, False], "coll": [15,16,17,18], "col3": ["e","f","g", "h"], "col4": [11,12,13,14]
})

# %%
df_3
# Out:
#    col1  col2   col3 col4
# 0     1     5   True    a
# 1     2     6  False    b
# 2     3     7  False    c
# 3     4     8   True    d

# %%
df_4
# Out:
#     col1  coll col3  col4
# 0   True    15    e    11
# 1  False    16    f    12
# 2   True    17    g    13
# 3  False    18    h    14

# %%
df_3 + df_4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:171, in _na_arithmetic_op(left, right, op, is_cmp)
#     170 try:
# --> 171     result = func(left, right)
#     172 except TypeError:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/computation/expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/computation/expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# TypeError: unsupported operand type(s) for +: 'bool' and 'str'
#
# ...
